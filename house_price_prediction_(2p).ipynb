# %%
import pandas as pd

data = {
    'Area': [1000,1500,1800,2400,3000],
    'Bedrooms': [2,3,3,4,4],
    'Price': [200000,300000,350000,450000,600000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Area  Bedrooms   Price
# 0  1000         2  200000
# 1  1500         3  300000
# 2  1800         3  350000
# 3  2400         4  450000
# 4  3000         4  600000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['Area','Bedrooms']]   # input
y = df['Price']               # output

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[2000,3]])
print("Predicted Price:", prediction)
# Out:
# Predicted Price: [401013.51351351]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Area'], df['Price'])
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("House Price vs Area")
plt.show()

# %% [markdown]
# Conclusion:
#
# In this project, we built a house price prediction model using Linear Regression.
# The model predicts price based on area and number of bedrooms.
# We observed that price increases as area increases.

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
print("Accuracy:", r2_score(y_test, y_pred))
# Out:
# Accuracy: nan
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
plt.scatter(df['Area'], df['Price'])
plt.plot(df['Area'], model.predict(df[['Area','Bedrooms']]), color='red')
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Regression Line")
plt.show()

# %% [markdown]
# Model Analysis:
#
# The model shows a positive relationship between area and price.
# As the area increases, the price also increases.
# The regression line fits the data reasonably well.

# %% [markdown]
# Conclusion:
#
# In this project, we developed a house price prediction model using Linear Regression.
# The model was trained using area and number of bedrooms as features.
# The results show that house prices increase with area.
# The model achieved a good accuracy score.
